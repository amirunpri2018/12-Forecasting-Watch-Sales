# %%
import numpy as np
import pandas as pd

#pd.options.display.precision=2
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import display

# %%
pd.set_option('max_rows', 10)
pd.set_option('precision', 10)

# %%
excel_data=pd.read_excel('SalesStats.xlsx')
excel_data.rename(columns={'YEAR':'Year'},inplace=True)
excel_data.head(3)
# Out:
#    Year                Store       Jan      Feb      Mar      Apr    May  \
# 0  2003      Agencia Bacolod  100618.8  67545.0  62699.1  55016.1  56048
# 1  2003      Centro - Butuan       NaN      NaN      NaN      NaN    NaN
# 2  2003  Centro - Catbalogan       NaN      NaN      NaN      NaN    NaN
#
#        Jun      Jul      Aug      Sep       Oct      Nov      Dec      Total
# 0  40477.1  30573.5  41342.6  37349.5  41871.05  28002.0  47260.5  608803.25
# 1      NaN      NaN      NaN      NaN       NaN      NaN      NaN       0.00
# 2      NaN      NaN      NaN      NaN       NaN      NaN      NaN       0.00

# %%
melt_data=excel_data.melt(id_vars=['Year','Store'], 
                  value_vars=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'],
                  var_name='Month', value_name='Sales')
melt_data.sort_values(['Year','Store'],inplace=True)
display(melt_data.head(3))
# Out:
#       Year            Store Month     Sales
# 0     2003  Agencia Bacolod   Jan  100618.8
# 1234  2003  Agencia Bacolod   Feb     67545
# 2468  2003  Agencia Bacolod   Mar   62699.1

# %%
from time import strptime
from datetime import datetime
melt_data['Date']=melt_data.apply(lambda row: datetime(row['Year'],(strptime(row['Month'],'%b').tm_mon),1),axis=1)

melt_data['Sales']=melt_data['Sales'].astype(str)
melt_data['Sales']=melt_data['Sales'].replace(r'\s+', np.nan, regex=True)
melt_data['Sales']=melt_data['Sales'].astype(float)
#melt_data.astype({'Sales':float},inplace=True)
#melt_data.dropna(inplace=True)
#melt_data.astype({'Sales':float})
display(melt_data.head(3))
# Out:
#       Year            Store Month     Sales       Date
# 0     2003  Agencia Bacolod   Jan  100618.8 2003-01-01
# 1234  2003  Agencia Bacolod   Feb   67545.0 2003-02-01
# 2468  2003  Agencia Bacolod   Mar   62699.1 2003-03-01

# %%
store_data=melt_data.drop(columns=['Year','Month'])
store_data.set_index('Date',inplace=True)
display(store_data.head(3))
# Out:
#                       Store     Sales
# Date
# 2003-01-01  Agencia Bacolod  100618.8
# 2003-02-01  Agencia Bacolod   67545.0
# 2003-03-01  Agencia Bacolod   62699.1

# %%
data=store_data.groupby('Date').sum()
display(data.head(3))
data.plot()
# Out:
#                        Sales
# Date
# 2003-01-01  2.2387705600e+06
# 2003-02-01  1.8763831500e+06
# 2003-03-01  2.0831725900e+06

# %%
from pandas.plotting import lag_plot
lag_plot(data)

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002DA34111F28>]],
#       dtype=object)

# %%
def dec_plot(data):
    from statsmodels.tsa.seasonal import seasonal_decompose
    result=seasonal_decompose(data,model='additive')
    result.plot()
    plt.show();

def corr_plot(data):
    from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
    acf=plot_acf(data,lags=25,zero=False)
    plt.axhline(y=-1.96/np.sqrt(len(data)),linestyle='--',color='gray')
    plt.axhline(y=1.96/np.sqrt(len(data)),linestyle='--',color='gray')
    pacf=plot_pacf(data,lags=25,zero=False)
    plt.show()
    
def adf_test(data):
    from statsmodels.tsa.stattools import adfuller
    result=adfuller(data['Sales'])
    df_res=pd.Series(result[0:4],index=['ADF Test Statistic','p-value','#lags used','# of observations'])
    for key,value in result[4].items():
        df_res['Critical value (%s)'%key]=value
    print(df_res)

# %%
adf_test(data)
# Out:
# ADF Test Statistic       -0.5235209269
# p-value                   0.8873442437
# #lags used               13.0000000000
# # of observations       166.0000000000
# Critical value (1%)      -3.4703698981
# Critical value (5%)      -2.8791138498
# Critical value (10%)     -2.5761394078
# dtype: float64

# %%
dec_plot(data)

# %%
seas_diff=data.diff(12)
seas_diff.dropna(inplace=True)
seas_diff.plot()

# %%
adf_test(seas_diff)
# Out:
# ADF Test Statistic       -2.6606099751
# p-value                   0.0811059794
# #lags used               14.0000000000
# # of observations       153.0000000000
# Critical value (1%)      -3.4738297757
# Critical value (5%)      -2.8806228997
# Critical value (10%)     -2.5769448985
# dtype: float64

# %%
first_diff=seas_diff.diff(1)
first_diff.dropna(inplace=True)
first_diff.plot()

# %%
adf_test(first_diff)
# Out:
# ADF Test Statistic       -5.1056919376
# p-value                   0.0000136542
# #lags used               13.0000000000
# # of observations       153.0000000000
# Critical value (1%)      -3.4738297757
# Critical value (5%)      -2.8806228997
# Critical value (10%)     -2.5769448985
# dtype: float64

# %%
first_diff.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002DA35364908>]],
#       dtype=object)

# %%
dec_plot(first_diff)

# %%
corr_plot(first_diff)

# %%
first_diff.index
# Out:
# DatetimeIndex(['2004-02-01', '2004-03-01', '2004-04-01', '2004-05-01',
#                '2004-06-01', '2004-07-01', '2004-08-01', '2004-09-01',
#                '2004-10-01', '2004-11-01',
#                ...
#                '2017-03-01', '2017-04-01', '2017-05-01', '2017-06-01',
#                '2017-07-01', '2017-08-01', '2017-09-01', '2017-10-01',
#                '2017-11-01', '2017-12-01'],
#               dtype='datetime64[ns]', name='Date', length=167, freq=None)

# %%
train_data=data.loc[data.index<'2017-01-01']

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,explained_variance_score
from statsmodels.tools.eval_measures import rmse
from statsmodels.tsa.statespace.sarimax import SARIMAX

def acc_score(data,show_res):
    n_data= data[data['Forecast'].notnull()]

    y_true=n_data['Sales']
    y_pred=n_data['Forecast']
    RMSE=rmse(y_true,y_pred)
    MAE=mean_absolute_error(y_true,y_pred)
    R2=r2_score(y_true,y_pred)
    MAPE=np.mean(np.abs((y_true-y_pred)/y_true))*100
    
    if show_res==True:
        print(' ERROR MEASURES ')
        print('Root Mean Squared Error: ', RMSE)
        print('Mean Absolute Error: ', MAE)
        print('Mean Absolute Percent Error: ', MAPE)
        print('R2 score: ', R2)
    
    return RMSE,MAE,R2,MAPE

def build_model(data,train_data,param,seasonal_param,show_res):
    data_forecast=data.copy()
   
    model=SARIMAX(train_data,order=param,seasonal_order=seasonal_param
                  ,enforce_stationarity=False, enforce_invertibility=False
                 )
    model_fit=model.fit()
    data_forecast['Forecast']=model_fit.forecast(steps=12)

    if show_res==True:
        print(model_fit.summary())
        
    return data_forecast,model_fit.aic

def grid_search(data,train_data):
    import itertools
    import warnings
    warnings.filterwarnings("ignore")
    
    p=d=q = range(0,3)
    
    pdq=list(itertools.product(p,d,q))
    PDQ=[(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
    
    arima_model=list()
    for param in pdq:
        for seasonal_param in PDQ:
            try:

                data_forecast,model_aic=build_model(data,train_data,param,seasonal_param,False)
                RMSE,MAE,R2,MAPE=acc_score(data_forecast,False)
                arima_model.append([param,seasonal_param,model_aic,RMSE,MAE,MAPE,R2])  
                
            except:
                continue
    columns=['pdq','PDQ','AIC','RMSE','MAE','MAPE','R2']
    grid_res=pd.DataFrame(arima_model,columns=columns)
    grid_res=grid_res.sort_values(by=['RMSE','MAE','MAPE'],ascending=True)
    print(len(arima_model),(len(grid_res)))

    return grid_res

# %%
print(len(train_data))
grid_res=grid_search(data,train_data)
#display(grid_res.head(10))
display(grid_res)
# Out:
# 168
# 720 720
#            pdq            PDQ              AIC              RMSE  \
# 101  (0, 1, 0)  (2, 2, 2, 12)  3386.7521809258  7.2870171503e+05
# 476  (1, 2, 2)  (2, 2, 2, 12)  3387.2173441681  1.2292545846e+06
# 719  (2, 2, 2)  (2, 2, 2, 12)  3389.6650358225  9.3618227377e+05
# 467  (1, 2, 2)  (1, 2, 2, 12)  3390.5695949071  6.5288526029e+05
# 458  (1, 2, 2)  (0, 2, 2, 12)  3391.0030982302  6.6990972734e+05
# ..         ...            ...              ...               ...
# 639  (2, 2, 0)  (0, 0, 0, 12)  5103.7251866981  1.5621789074e+07
# 234  (1, 0, 0)  (0, 0, 0, 12)  5148.0702817429  2.6014153112e+06
# 396  (1, 2, 0)  (0, 0, 0, 12)  5182.8573000817  2.2294795143e+07
# 51   (0, 0, 2)  (0, 0, 0, 12)  5273.7156722426  4.0376842119e+06
# 24   (0, 0, 1)  (0, 0, 0, 12)  5320.8976007711  4.1147123549e+06
#
#                   MAE            MAPE              R2
# 101  6.5415637735e+05   16.9434211398    0.8188028781
# 476  8.9048591586e+05   21.0049570454    0.4843733148
# 719  6.9097544250e+05   16.3059950788    0.7009302145
# 467  5.0174985778e+05   12.6475127567    0.8545460767
# 458  5.9831815537e+05   16.9795406312    0.8468615384
# ..                ...             ...             ...
# 639  1.4496408860e+07  401.1168635857  -82.2747334380
# 234  1.9503957591e+06   48.7715006869   -1.3092507642
# 396  2.0531213989e+07  563.3727416621 -168.6128236670
# 51   3.5159275696e+06   89.3670428923   -4.5630941658
# 24   3.6343146770e+06   93.1957916587   -4.7773765338
#
# [720 rows x 7 columns]

# %%
#display(grid_res.sort_values(by=['AIC'],ascending=True).head(3))

# %%
result,aic=build_model(data,train_data,(1,2,2),(1,0,1,12),True)
acc_score(result,True)
test_data=result.loc[result.index>='2017-01-01']
test_data.plot()
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                              Sales   No. Observations:                  168
# Model:             SARIMAX(1, 2, 2)x(1, 0, 1, 12)   Log Likelihood               -2263.621
# Date:                            Tue, 27 Mar 2018   AIC                           4539.243
# Time:                                    19:12:27   BIC                           4557.986
# Sample:                                01-01-2003   HQIC                          4546.850
#                                      - 12-01-2016
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1585      1.178      0.135      0.893      -2.150       2.467
# ma.L1         -1.5255      1.072     -1.423      0.155      -3.627       0.576
# ma.L2          0.5860      0.986      0.594      0.552      -1.347       2.518
# ar.S.L12       1.0489      0.096     10.873      0.000       0.860       1.238
# ma.S.L12      -0.4625      0.369     -1.253      0.210      -1.186       0.261
# sigma2      1.503e+12   3.92e-14   3.84e+25      0.000     1.5e+12     1.5e+12
# ===================================================================================
# Ljung-Box (Q):                       54.59   Jarque-Bera (JB):                11.10
# Prob(Q):                              0.06   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.30   Skew:                             0.11
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.31
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 9.21e+42. Standard errors may be unstable.
#  ERROR MEASURES
# Root Mean Squared Error:  624230.9237583599
# Mean Absolute Error:  481735.7668878998
# Mean Absolute Percent Error:  12.406597813078077
# R2 score:  0.8670334897726868

# %%
model=SARIMAX(data,order=(1,2,2),seasonal_order=(1,0,1,12),enforce_stationarity=False, enforce_invertibility=False)
model_fit=model.fit()
print(model_fit.summary())
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                              Sales   No. Observations:                  180
# Model:             SARIMAX(1, 2, 2)x(1, 0, 1, 12)   Log Likelihood               -2451.840
# Date:                            Tue, 27 Mar 2018   AIC                           4915.681
# Time:                                    19:12:35   BIC                           4934.838
# Sample:                                01-01-2003   HQIC                          4923.448
#                                      - 12-01-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1048      1.206      0.087      0.931      -2.259       2.468
# ma.L1         -1.5117      1.112     -1.360      0.174      -3.690       0.667
# ma.L2          0.5755      1.022      0.563      0.573      -1.427       2.578
# ar.S.L12       1.0674      0.086     12.384      0.000       0.898       1.236
# ma.S.L12      -0.4973      0.386     -1.288      0.198      -1.254       0.259
# sigma2      1.665e+12   1.49e-14   1.11e+26      0.000    1.66e+12    1.66e+12
# ===================================================================================
# Ljung-Box (Q):                       49.84   Jarque-Bera (JB):                26.78
# Prob(Q):                              0.14   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.23   Skew:                             0.29
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.90
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 9.76e+42. Standard errors may be unstable.

# %%
print('Final Forecast')
forecast_results=model_fit.forecast(steps=12)
forecast_results.rename('Forecast',inplace=True)
forecast_data=pd.concat((data,forecast_results),axis=1)
forecast_data.plot(figsize=(12,8))
plt.show()
print(forecast_results)
# Out:
# Final Forecast
# 2018-01-01    5.3545823516e+06
# 2018-02-01    4.8807814064e+06
# 2018-03-01    5.2750455635e+06
# 2018-04-01    5.1355450107e+06
# 2018-05-01    5.6768267861e+06
#                     ...
# 2018-08-01    5.9010665280e+06
# 2018-09-01    5.9594621059e+06
# 2018-10-01    6.2392729043e+06
# 2018-11-01    6.5370496919e+06
# 2018-12-01    1.2226189152e+07
# Freq: MS, Name: Forecast, Length: 12, dtype: float64

# %%
test_data=forecast_data.loc[forecast_data.index>='2016-01-01']
test_data.plot(figsize=(12,8))
plt.show()

# %%
writer=pd.ExcelWriter('forecast.xlsx')
forecast_data.to_excel(writer,'2018_forecast')
writer.save()
